# %% [markdown]
# ## Descipcion de los ejercios
# Ejercicio 1. Contesta las siguientes preguntas.
# - a) ¿Cuántas filas tiene el Dataset? 7198
# - b) ¿Cuántas columnas tiene el Dataset? 17
# - c) El índice de la columna ‘id’ es 1, ¿cuál es el índice de la columna ‘size_bytes’? 3
# - d) El índice de la columna ‘id’ es 1, ¿cuál es el índice de la columna ‘currency’? 4
# - e) El índice de la columna ‘id’ es 1, ¿cuál es el índice de la columna ‘price? 5

# %%
import os
os.listdir('/Users/ani/Documents/reposis/2024-T3-MSR-2C-230110616/ApleStore.cvs')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/ani/Documents/reposis/2024-T3-MSR-2C-230110616/examen-tema-3.ipynb Celda 2 line 2
#       <a href='vscode-notebook-cell:/Users/ani/Documents/reposis/2024-T3-MSR-2C-230110616/examen-tema-3.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import os
# ----> <a href='vscode-notebook-cell:/Users/ani/Documents/reposis/2024-T3-MSR-2C-230110616/examen-tema-3.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> os.listdir('/Users/ani/Documents/reposis/2024-T3-MSR-2C-230110616/ApleStore.cvs')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/ani/Documents/reposis/2024-T3-MSR-2C-230110616/ApleStore.cvs'

# %%
opened_file = open('/Users/ani/Documents/reposis/2024-T3-MSR-2C-230110616/ApleStore.cvs')
print(opened_file)
# Out:
# <_io.TextIOWrapper name='/kaggle/input/AppleStore.csv' mode='r' encoding='UTF-8'>

# %% [markdown]
# Ejercicio 2. Trabaja con la columna ‘track_name’ y contesta los siguientes planteamientos.
# - a) ¿Cuántos caracteres tiene el nombre de aplicación más largo y cuál es el nombre?
# - b) ¿Cuántos caracteres tiene el nombre de aplicación más corto y cuál es el nombre?
# - c) ¿Cuál es número promedio de caracteres que tiene el nombre de una aplicación en este Dataset?
# - d) ¿Cuál es la varianza y la desviación estándar en el número de caracteres que conforman el nombre de
# una aplicación en este Dataset?
# - e) Grafica el histograma con las siguientes características:
# • Etiqueta del eje x como ‘índice’.
# • Etiqueta del eje y como ‘Numero de caracteres’.
# • Título del histograma ‘Nombres de aplicación’.
